# %% [markdown]
# # MLP
# Laden des auf IDS17 trainierten Modells
# Test auf IDS18 mit reduzierten Benign Daten

# %%
import os
import logging
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import tensorflow as tf
import keras
import joblib
from sklearn.metrics import classification_report, confusion_matrix
# Out:
# 2024-11-18 21:26:38.350565: I tensorflow/core/util/port.cc:153] oneDNN custom operations are on. You may see slightly different numerical results due to floating-point round-off errors from different computation orders. To turn them off, set the environment variable `TF_ENABLE_ONEDNN_OPTS=0`.
# 2024-11-18 21:26:38.411868: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:485] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# 2024-11-18 21:26:38.466296: E external/local_xla/xla/stream_executor/cuda/cuda_dnn.cc:8454] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# 2024-11-18 21:26:38.481719: E external/local_xla/xla/stream_executor/cuda/cuda_blas.cc:1452] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# 2024-11-18 21:26:38.530489: I tensorflow/core/platform/cpu_feature_guard.cc:210] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 AVX_VNNI FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2024-11-18 21:26:39.442928: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Could not find TensorRT

# %%
# Maximale Zeilen und Spalten anzeigen
pd.set_option('display.max_rows', None)  # Zeilen
pd.set_option('display.max_columns', None)  # Spalten

# Logging Parameter
logging.basicConfig(
    #filename='32_cnn_test.log',
    level=logging.INFO,
    format='%(asctime)s - %(levelname)s - %(message)s',
    datefmt='%Y-%m-%d %H:%M:%S'
)

# Verzeichnis der CSV-Dateien
ids17_prep_1 = '../01_Datensaetze/improved_cic-ids-2017/ids17_parquet_prep_1/ids17.parquet'
ids18_prep_1 = '../01_Datensaetze/improved_cse-cic-ids-2018/ids18_parquet_prep_1/ids18.parquet'
hybrid_train_prep_1 =  '../01_Datensaetze/improved_hybrid_b17/hybrid_parquet_prep_1/hybrid_b17_train.parquet'
hybrid_test_prep_1 = '../01_Datensaetze/improved_hybrid_b17/hybrid_parquet_prep_1/hybrid_b17_test.parquet'

# %% [markdown]
# ### Laden von IDS18

# %%
# Datensatz einlesen
df = pd.read_parquet(ids18_prep_1)
logging.info("Class distribution\n{}".format(df.Label.value_counts()))
print(df.shape)
print(df.columns)
# Out:
# 2024-11-18 21:26:40 - INFO - Class distribution
# Label
# BENIGN                          2967676
# DoS Hulk                        1803160
# DDoS-LOIC-HTTP                   289328
# Botnet Ares                      142921
# SSH-BruteForce                    94197
# Infiltration - NMAP Portscan      89374
# DoS GoldenEye                     22560
# DoS Slowloris                      8490
# Name: count, dtype: int64
# (5417706, 52)
# Index(['Fwd IAT Total', 'Dst Port', 'FIN Flag Count', 'Packet Length Variance',
#        'Down/Up Ratio', 'Bwd Packet Length Min', 'Bwd Packet Length Mean',
#        'URG Flag Count', 'Bwd Packets/s', 'Total TCP Flow Time',
#        'Bwd Bulk Rate Avg', 'Total Length of Fwd Packet', 'Bwd IAT Mean',
#        'Bwd Packet/Bulk Avg', 'Fwd IAT Max', 'Protocol', 'Flow IAT Min',
#        'Bwd Header Length', 'Active Max', 'Total Fwd Packet',
#        'Subflow Bwd Packets', 'Fwd Header Length', 'Fwd Seg Size Min',
#        'Fwd RST Flags', 'Idle Std', 'Fwd Packet Length Min',
#        'Bwd Init Win Bytes', 'Bwd Packet Length Std', 'RST Flag Count',
#        'Fwd Act Data Pkts', 'Subflow Fwd Packets', 'ECE Flag Count',
#        'SYN Flag Count', 'Bwd URG Flags', 'Average Packet Size', 'Bwd IAT Max',
#        'Bwd PSH Flags', 'Total Length of Bwd Packet', 'Bwd RST Flags',
#        'Flow Bytes/s', 'Fwd Bulk Rate Avg', 'Fwd IAT Min', 'Active Std',
#        'Packet Length Max', 'Bwd IAT Total', 'Fwd IAT Mean', 'Flow IAT Mean',
#        'Bwd IAT Min', 'FWD Init Win Bytes', 'Fwd PSH Flags', 'Active Min',
#        'Label'],
#       dtype='object')

# %% [markdown]
# ### Trennen von Features und Labels

# %%
X = df.iloc[:, :-1]  # Alle Spalten außer der letzten
print("Form von X:", X.shape)
y = df.iloc[:, -1]   # Die letzte Spalte
print("Form von y:", y.shape)
# Out:
# Form von X: (5417706, 51)
# Form von y: (5417706,)

# %% [markdown]
# ### Label Encoding für y

# %%
label_encoder = joblib.load('label_encoder.pkl')
y_encoded = label_encoder.fit_transform(y)

print("Einzigartige Labels:", label_encoder.classes_)
print("Kodierte Labels:", np.unique(y_encoded))
# Out:
# Einzigartige Labels: ['BENIGN' 'Botnet Ares' 'DDoS-LOIC-HTTP' 'DoS GoldenEye' 'DoS Hulk'
#  'DoS Slowloris' 'Infiltration - NMAP Portscan' 'SSH-BruteForce']
# Kodierte Labels: [0 1 2 3 4 5 6 7]

# %% [markdown]
# ### Skallierung von X

# %%
scaler = joblib.load('scaler.pkl')
X_scaled = scaler.fit_transform(X)

print("Form von X:", X.shape)
print("Form von X_scaled:", X_scaled.shape)
# Out:
# Form von X: (5417706, 51)
# Form von X_scaled: (5417706, 51)

# %%
X_test, y_test = X_scaled, y_encoded
X_test.shape, y_test.shape
# Out:
# ((5417706, 51), (5417706,))

# %% [markdown]
# ### Überprüfen der Klassenverteilung

# %%
def print_class_distribution(y, dataset_name):
    unique, counts = np.unique(y, return_counts=True)
    total = len(y)
    print(f"Klassenverteilung in {dataset_name}:")
    for cls, count in zip(unique, counts):
        print(f"  Klasse {cls}: {count} Beispiele ({(count/total)*100:.2f}%)")
    print()

print_class_distribution(y_test, "Testdatensatz")
# Out:
# Klassenverteilung in Testdatensatz:
#   Klasse 0: 2967676 Beispiele (54.78%)
#   Klasse 1: 142921 Beispiele (2.64%)
#   Klasse 2: 289328 Beispiele (5.34%)
#   Klasse 3: 22560 Beispiele (0.42%)
#   Klasse 4: 1803160 Beispiele (33.28%)
#   Klasse 5: 8490 Beispiele (0.16%)
#   Klasse 6: 89374 Beispiele (1.65%)
#   Klasse 7: 94197 Beispiele (1.74%)

# %% [markdown]
# ### Laden des Modells

# %%
model = keras.models.load_model('model.keras')
# Out:
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# I0000 00:00:1731961628.709874  594975 cuda_executor.cc:1001] could not open file to read NUMA node: /sys/bus/pci/devices/0000:01:00.0/numa_node
# Your kernel may have been built without NUMA support.
# I0000 00:00:1731961628.795270  594975 cuda_executor.cc:1001] could not open file to read NUMA node: /sys/bus/pci/devices/0000:01:00.0/numa_node
# Your kernel may have been built without NUMA support.
# I0000 00:00:1731961628.795308  594975 cuda_executor.cc:1001] could not open file to read NUMA node: /sys/bus/pci/devices/0000:01:00.0/numa_node
# Your kernel may have been built without NUMA support.
# I0000 00:00:1731961628.797431  594975 cuda_executor.cc:1001] could not open file to read NUMA node: /sys/bus/pci/devices/0000:01:00.0/numa_node
# Your kernel may have been built without NUMA support.
# I0000 00:00:1731961628.797464  594975 cuda_executor.cc:1001] could not open file to read NUMA node: /sys/bus/pci/devices/0000:01:00.0/numa_node
# Your kernel may have been built without NUMA support.
# I0000 00:00:1731961628.797479  594975 cuda_executor.cc:1001] could not open file to read NUMA node: /sys/bus/pci/devices/0000:01:00.0/numa_node
# Your kernel may have been built without NUMA support.
# I0000 00:00:1731961628.959932  594975 cuda_executor.cc:1001] could not open file to read NUMA node: /sys/bus/pci/devices/0000:01:00.0/numa_node
# Your kernel may have been built without NUMA support.
# I0000 00:00:1731961628.959999  594975 cuda_executor.cc:1001] could not open file to read NUMA node: /sys/bus/pci/devices/0000:01:00.0/numa_node
# Your kernel may have been built without NUMA support.
# 2024-11-18 21:27:08.960045: I tensorflow/core/common_runtime/gpu/gpu_device.cc:2112] Could not identify NUMA node of platform GPU id 0, defaulting to 0.  Your kernel may not have been built with NUMA support.
# I0000 00:00:1731961628.960086  594975 cuda_executor.cc:1001] could not open file to read NUMA node: /sys/bus/pci/devices/0000:01:00.0/numa_node
# Your kernel may have been built without NUMA support.
# 2024-11-18 21:27:08.960123: I tensorflow/core/common_runtime/gpu/gpu_device.cc:2021] Created device /job:localhost/replica:0/task:0/device:GPU:0 with 4792 MB memory:  -> device: 0, name: NVIDIA GeForce RTX 4060, pci bus id: 0000:01:00.0, compute capability: 8.9

# %% [markdown]
# ### Evaluierung des Modells auf dem Testdatensatz

# %%
test_loss, test_accuracy = model.evaluate(X_test, y_test)
print(f"Testverlust: {test_loss:.4f}")
print(f"Testgenauigkeit: {test_accuracy:.4f}")
# Out:
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# I0000 00:00:1731961632.887816  595236 service.cc:146] XLA service 0x7f4e0c0054a0 initialized for platform CUDA (this does not guarantee that XLA will be used). Devices:
# I0000 00:00:1731961632.887884  595236 service.cc:154]   StreamExecutor device (0): NVIDIA GeForce RTX 4060, Compute Capability 8.9
# 2024-11-18 21:27:12.896248: I tensorflow/compiler/mlir/tensorflow/utils/dump_mlir_util.cc:268] disabling MLIR crash reproducer, set env var `MLIR_CRASH_REPRODUCER_DIRECTORY` to enable.
# 2024-11-18 21:27:12.931609: I external/local_xla/xla/stream_executor/cuda/cuda_dnn.cc:531] Loaded cuDNN version 8907
#    155/169304 ━━━━━━━━━━━━━━━━━━━━ 2:45 978us/step - loss: 0.0488 - sparse_categorical_accuracy: 0.9770
# I0000 00:00:1731961633.628341  595236 device_compiler.h:188] Compiled cluster using XLA!  This line is logged at most once for the lifetime of the process.
# 169304/169304 ━━━━━━━━━━━━━━━━━━━━ 160s 937us/step - loss: 22.8020 - sparse_categorical_accuracy: 0.7718
# Testverlust: 48.1882
# Testgenauigkeit: 0.5350

# %% [markdown]
# ### Klassifikationsbericht und eine Konfusionsmatrix

# %%
# Vorhersagen auf dem Testdatensatz
y_pred_prob = model.predict(X_test)
y_pred_classes = np.argmax(y_pred_prob, axis=1)

# Klassifikationsbericht
print(classification_report(y_test, y_pred_classes, target_names=label_encoder.classes_))

# Konfusionsmatrix
cm = confusion_matrix(y_test, y_pred_classes)
# Out:
# 169304/169304 ━━━━━━━━━━━━━━━━━━━━ 128s 756us/step
# /home/michi/BA/.venv/lib/python3.10/site-packages/sklearn/metrics/_classification.py:1531: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# /home/michi/BA/.venv/lib/python3.10/site-packages/sklearn/metrics/_classification.py:1531: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# /home/michi/BA/.venv/lib/python3.10/site-packages/sklearn/metrics/_classification.py:1531: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
#                               precision    recall  f1-score   support
#
#                       BENIGN       0.54      0.97      0.70   2967676
#                  Botnet Ares       1.00      0.00      0.00    142921
#               DDoS-LOIC-HTTP       0.00      0.00      0.00    289328
#                DoS GoldenEye       0.84      0.04      0.07     22560
#                     DoS Hulk       0.00      0.00      0.00   1803160
#                DoS Slowloris       0.80      0.90      0.85      8490
# Infiltration - NMAP Portscan       0.02      0.02      0.02     89374
#               SSH-BruteForce       0.00      0.00      0.00     94197
#
#                     accuracy                           0.53   5417706
#                    macro avg       0.40      0.24      0.21   5417706
#                 weighted avg       0.33      0.53      0.38   5417706

# %% [markdown]
# Visualisierung der Konfusionsmatrix

# %%
plt.figure(figsize=(8, 6))
sns.heatmap(cm, annot=True, fmt='d', cmap='Blues',
            xticklabels=label_encoder.classes_,
            yticklabels=label_encoder.classes_)
plt.xlabel('Vorhergesagte Klasse')
plt.ylabel('Wahre Klasse')
plt.title('Konfusionsmatrix')
plt.show()
